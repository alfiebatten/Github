# %% [markdown]
# # START OF A TEXT BASED GAME
# ### ` M Y  F I R S T  A T T E M P T`

# %%
#Setup 
import time
print("\033[1;30;1m")

#Intro asking for name
name = input("Whats your name? ")
time.sleep(0.8)
print("Hey",name ,"welcome to Adventure Resort")
time.sleep(1)
print("        ")

#Character choices 
print("Choose A Character...")
time.sleep(1)
print("\033[1;32;1m Baboshka - An overweight warriror of the north, EXTREMELY STRONG")
print("\033[1;33;1m Shaboola - The most skillfull female assassin in the whole of China, sharpest blade in the world")
print("\033[1;31;1m Tim - A skinny schoolkid from England")
time.sleep(7)
print("\033[1;30;1m")

#Character decision
character = (input("Who are you going to choose? "))
time.sleep(1)
if character == "Baboshka" or character =="baboshka":
    print("Welcome \033[1;32;1m Baboshka \033[1;30;1m to the field")
elif character == "Shaboola" or character == "shaboola":
    print("Welcome \033[1;33;1m Shaboola \033[1;30;1m to the field")
elif character == "Tim" or character == "tim":
    print("Welcome \033[1;31;1m Tim \033[1;30;1m to the field")
else:
    print("Invalid Character Selection")
    character = (input("Who are you going to choose? "))
    time.sleep(1)
    if character == "Baboshka" or character =="baboshka":
        print("Welcome \033[1;32;1m Baboshka \033[1;30;1m to the field")
    elif character == "Shaboola" or character == "shaboola":
        print("Welcome \033[1;33;1m Shaboola \033[1;30;1m to the field")
    elif character == "Tim" or character == "tim":
        print("Welcome \033[1;31;1m Tim \033[1;30;1m to the field")
time.sleep(1.2)   

#Location choices
print("      ")
print("You have now chosen your character, but where will they land...")
time.sleep(1)
print("\033[1;32;1m The Jungle")
print("\033[1;33;1m The Desert")
print("\033[1;31;1m The City")
time.sleep(3)
print("\033[1;30;1m")

#Location Decision
place = input("Choose an enviroment... ")
time.sleep(1)
print("      ")
if place == "The Jungle" or place == "the jungle" or place == "The jungle" or place == "Jungle" or place == "jungle":
    print("\033[1;32;1m Jungle \033[1;34;1m loading...")
    time.sleep(1.5)
    print("\033[1;32;1m Jungle \033[1;34;1m loaded")
elif place == "The Desert" or place == "the desert" or place == "The desert" or place == "Desert" or place == "desert":
        print("\033[1;33;1m Desert \033[1;34;1m loading...")
        time.sleep(1.5)
        print("\033[1;33;1m Desert \033[1;34;1m loaded")
elif place == "The City" or place == "the city" or place == "The city" or place == "City" or place == "city":
    print("\033[1;33;1m City \033[1;34;1m loading...") 
    time.sleep(1.5)
    print("\033[1;33;1m City \033[1;34;1m loaded")
else:
    print("\033[1;30;1m")
    print("Invalid enviroment")
    place = input("Choose an enviroment... ")
    if place == "The Jungle" or place == "the jungle" or place == "The jungle" or place == "Jungle" or place == "jungle":
        print("\033[1;32;1m Jungle \033[1;34;1m loading...")
        time.sleep(1.5)
        print("\033[1;32;1m Jungle \033[1;34;1m loaded")
    elif place == "The Desert" or place == "the desert" or place == "The desert" or place == "Desert" or place == "desert":
        print("\033[1;33;1m Desert \033[1;34;1m loading...")
        time.sleep(1.5)
        print("\033[1;33;1m Desert \033[1;34;1m loaded")
    elif place == "The City" or place == "the city" or place == "The city" or place == "City" or place == "city":
        print("\033[1;33;1m City \033[1;34;1m loading...") 
        time.sleep(1.5)
        print("\033[1;33;1m City \033[1;34;1m loaded")
time.sleep(1)

#Game starting
print("\033[1;30;1m")
print("You are now ready to play!")
import random
time.sleep(0.8)
print("        ")
print("You have landed in your location")
time.sleep(0.8)
print("Survive!")
from random import randint
time.sleep(1)

choicea = input()
#Jungle
if place == "The Jungle" or place == "the jungle" or place == "Jungle" or place == "jungle":
    print(character,"looks around to see what he can find")
    time.sleep(1.5)
    print("Theres a large tree up ahead or a cave to the right")
    time.sleep(0.8)
    choicea = input("Which will you choose?")
    time.sleep(0.8)
    if choicea == "Cave" or choicea == "cave":
        print(character, "goes towards the cave and slowly walks in")
        num = randint(0, 9)
        if num == 1:
            print("A swarm of bats swoops down from the cave and eats", character, "alive")
            print("GAME OVER!")
        else:
            print("as", character, "is walking they come across a flaming torch and an arrow")
            choiceb == input("Your bag is only big enough to fit one of the items, which will you choose?")
            if choiceb == "Flaming torch" or choiceb == "flaming torch" or choiceb == "Torch" or choiceb == "torch":
                print(character, "picks up the torch and heads deader down into the cave")
                print(character, "spots a waterfall up ahead and as its the only way down has to climb down it")
                num = randint(0,4)
                if num == 1:
                    print("Unfortunatly", character, "steps on a rock that slips and plummets to their death")
                    print("GAME OVER!")
                else:
                    print("Splish Splosh Splish Splosh")
                    print(character, "successfully makes it down the waterfall alive and comes into a huge room carved out by Romans")
                    print("Theres an exit at the other side of the room")
                    choicec = input("Does", character, "go to the exit or look around the room?")
                    if choicec == "Walk to exit" or choicec == "walk to exit" or choicec == "Go to exit" or choicec == "go to exit" or choicec == "Exit" or choicec == "exit":
                        num = randint(0,9)
                        if num == 1:
                            print(character, "walks across the room and goes out the exit")
                            print("YOU WIN!")
                            print("CONGRATULATIONS, please follow my insta alfie.batten :)")
                        else:
                            print(character, "walks across the room and gets stopped by a HUGE Greek God who appears from nowhere")
                            if choiceb == "Flaming torch" or choiceb == "flaming torch" or choiceb == "Torch" or choiceb == "torch":
                                print(character, "takes out their flaming torch and throws it at the God")
                                print("The God hates fire and screams and burns to the floor")
                                choiced = input(character, "killed the god, does he run out the exit or continue to look around?")
                                if choiced == "Run out exit" or choiced == "run out exit" or choiced == "Run" or choiced == "run":
                                    print(character, "runs out the exit and escapes")
                                    print("YOU WIN!")
                                    print("CONGRATULATIONS, please follow my insta alfie.batten :)")
                                elif choiced == "Continue to look around" or choiced == "continue to look around" or choiced == "Look around" or choiced == "look around" or choiced == "Look" or choiced == "look":
                                    num = randint(0,5)
                                    if num == 1:
                                        print(character, "looks around, finds nothing, and walks out")
                                        print("YOU WIN!")
                                        print("CONGRATULATIONS, please follow my insta alfie.batten :)")
                                    else:
                                        print(character, "walks around and while doing so the God comes back to life and eats", character)
                                        print("GAME OVER!")
# Out:
# Whats your name? alfie
# Hey alfie welcome to Adventure Resort
#
# Choose A Character...
#  Baboshka - An overweight warriror of the north, EXTREMELY STRONG
#  Shaboola - The most skillfull female assassin in the whole of China, sharpest blade in the world
#  Tim - A skinny schoolkid from England
#
# Who are you going to choose? tim
# Welcome  Tim  to the field
#
# You have now chosen your character, but where will they land...
#  The Jungle
#  The Desert
#  The City
#
# Choose an enviroment... jungle
#
#  Jungle  loading...
#  Jungle  loaded
#
# You are now ready to play!
#
# You have landed in your location
# Survive!
# kk pengting
# tim looks around to see what he can find
# Theres a large tree up ahead or a cave to the right
# Which will you choose?cave
# tim goes towards the cave and slowly walks in
# as tim is walking they come across a flaming torch and an arrow
# ---------------------------------------------------------------------------
# ...
